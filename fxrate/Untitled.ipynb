# %%
# %%time
import bars
# Out:
# CPU times: user 257 ms, sys: 54.3 ms, total: 311 ms
# Wall time: 351 ms

# %%
# %%time
bars.create_1m_bar()
# Out:
# CPU times: user 34.8 s, sys: 1.89 s, total: 36.7 s
# Wall time: 37 s

# %%
# %%time
bars.create_30m_1d_bar()
# Out:
# 30 20070201.0
# 30 20070301.0
# 30 20070401.0
# 30 20070501.0
# 30 20070601.0
# 30 20070701.0
# 30 20070801.0
# 30 20070901.0
# 30 20071001.0
# 30 20071101.0
# 30 20071201.0
# 30 20080101.0
# 30 20080201.0
# 30 20080301.0
# 30 20080401.0
# 30 20080501.0
# 30 20080601.0
# 30 20080701.0
# 30 20080801.0
# 30 20080901.0
# 30 20081001.0
# 30 20081101.0
# 30 20081201.0
# 30 20090101.0
# 30 20090201.0
# 30 20090301.0
# 30 20090401.0
# 30 20090501.0
# 30 20090601.0
# 30 20090701.0
# 30 20090801.0
# 30 20090901.0
# 30 20091001.0
# 30 20091101.0
# 30 20091201.0
# 30 20100101.0
# 30 20100201.0
# 30 20100301.0
# 30 20100401.0
# 30 20100501.0
# 30 20100601.0
# 30 20100701.0
# 30 20100801.0
# 30 20100901.0
# 30 20101001.0
# 30 20101101.0
# 30 20101201.0
# 30 20110101.0
# 30 20110201.0
# 30 20110301.0
# 30 20110401.0
# 30 20110501.0
# 30 20110601.0
# 30 20110701.0
# 30 20110801.0
# 30 20110901.0
# 30 20111001.0
# 30 20111101.0
# 30 20111201.0
# 30 20120101.0
# 30 20120201.0
# 30 20120301.0
# ...

# %%
# %%time
bars.add_ma()
# Out:
# CPU times: user 7.16 s, sys: 86.4 ms, total: 7.25 s
# Wall time: 7.27 s

# %%
# %%time
import bars 
bars.load_bars(10)
# Out:
# CPU times: user 52.3 ms, sys: 103 ms, total: 155 ms
# Wall time: 154 ms
