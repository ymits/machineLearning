# %%
import bars

# %%
# %%time
(x_train, t_train) = bars.load_bars(10)

print(x_train.shape)
print(t_train.shape)
# Out:
# (20211, 10, 14)
# (20211, 3)
# CPU times: user 39.8 s, sys: 44 ms, total: 39.8 s
# Wall time: 39.9 s

# %%
x_train[0:1]
# Out:
# array([[[ 108.9275    ,  109.079     ,  108.846     ,  109.0545    ,
#           108.888     ,  108.98852   ,  108.71605333,  106.331     ,
#           106.819     ,  106.145     ,  106.4135    ,  109.752     ,
#           110.08314   ,  113.20706667],
#         [ 109.0545    ,  109.11      ,  109.021     ,  109.0785    ,
#           108.8751    ,  108.9938    ,  108.7192    ,  106.4135    ,
#           107.412     ,  105.549     ,  106.9455    ,  109.50835   ,
#           109.80382   ,  113.06160667],
#         [ 109.0785    ,  109.154     ,  109.041     ,  109.1275    ,
#           108.8759    ,  109.0006    ,  108.72293333,  106.9455    ,
#           107.361     ,  106.254     ,  107.0355    ,  109.27605   ,
#           109.57344   ,  112.919     ],
#         [ 109.1275    ,  109.127     ,  109.064     ,  109.0855    ,
#           108.9066    ,  109.0094    ,  108.72689333,  107.0355    ,
#           107.501     ,  106.803     ,  107.275     ,  109.00585   ,
# ...

# %%
x_train[0:1]
# Out:
# array([[[-8.51851852e-01,  5.50925926e-01, -1.60648148e+00,
#           3.24074074e-01, -1.21759259e+00, -2.86851852e-01,
#          -2.80969136e+00, -2.48935185e+01, -2.03750000e+01,
#          -2.66157407e+01, -2.41296296e+01,  6.78240741e+00,
#           9.84851852e+00,  3.87737654e+01],
#         [ 3.24074074e-01,  8.37962963e-01,  1.38888889e-02,
#           5.46296296e-01, -1.33703704e+00, -2.37962963e-01,
#          -2.78055556e+00, -2.41296296e+01, -1.48842593e+01,
#          -3.21342593e+01, -1.92037037e+01,  4.52638889e+00,
#           7.26222222e+00,  3.74269136e+01],
#         [ 5.46296296e-01,  1.24537037e+00,  1.99074074e-01,
#           1.00000000e+00, -1.32962963e+00, -1.75000000e-01,
#          -2.74598765e+00, -1.92037037e+01, -1.53564815e+01,
#          -2.56064815e+01, -1.83703704e+01,  2.37546296e+00,
#           5.12907407e+00,  3.61064815e+01],
#         [ 1.00000000e+00,  9.95370370e-01,  4.12037037e-01,
# ...
